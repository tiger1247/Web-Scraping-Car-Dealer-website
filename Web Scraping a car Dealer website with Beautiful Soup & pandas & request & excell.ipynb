# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
name = []
milease = []
dealer_name = []

# looping all the 10 pages
for i in range(1,11):
    
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=mercedes_benz&maximum_distance=20&models[]=&stock_type=all&zip='
    
    # request to website
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # results
    results = soup.find_all('div',{'class':'vehicle-card'})    
    
    for result in results:
        # name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('n/a')
            
        # milease
        try:
            milease.append(result.find('div',{'class':'mileage'}).get_text())
        except:
            milease.append('n/a')
    
        # dealer name
        try:
            dealer_name.append(result.find('div',{'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

# %%
car_dealer = pd.DataFrame({
    'Name':name, "Milease":milease, "Dealer Name":dealer_name
})

# %%
car_dealer
# Out:
#                                                   Name     Milease  \
# 0              2020 Mercedes-Benz AMG C 43 Base 4MATIC  14,000 mi.
# 1                     2019 Mercedes-Benz AMG G 63 Base  35,233 mi.
# 2                     2016 Mercedes-Benz G-Class G 550  36,474 mi.
# 3              2015 Mercedes-Benz S-Class S 550 4MATIC  42,370 mi.
# 4          2016 Mercedes-Benz GLA-Class GLA 250 4MATIC  49,623 mi.
# ..                                                 ...         ...
# 195                    2019 Mercedes-Benz GLC 300 Base  33,368 mi.
# 196  2018 Mercedes-Benz GLE 550e Plug-In Hybrid Bas...  41,233 mi.
# 197                    2021 Mercedes-Benz GLC 300 Base  21,858 mi.
# 198                    2019 Mercedes-Benz GLC 300 Base  22,176 mi.
# 199       2017 Mercedes-Benz AMG GLE 63 S Coupe 4MATIC  28,240 mi.
#
#                         Dealer Name
# 0         Wholesale Luxury Cars LLC
# 1         Maserati of Newport Beach
# 2               Porsche Downtown LA
# ...

# %%
car_dealer.to_excel('Multiple page cars.xlsx', index=False)
